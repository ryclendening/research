# %%
import librosa
import pandas as pd
from librosa.effects import pitch_shift
import os
from sklearn.metrics import classification_report
import pathlib
import random
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from librosa.feature import mfcc, melspectrogram
import scipy.io.wavfile as wav
import tensorflow as tf
import scipy.signal as signal
import keras
from sklearn.model_selection import train_test_split
from keras.models import Model
from research.dataImporting import MLtools
from keras.optimizers import adam_v2
from keras.layers import Input, Conv1D, Conv2D, Conv3D,SeparableConv1D, MaxPooling1D,MaxPooling2D,MaxPooling3D, Flatten, Dense, Dropout, \
    BatchNormalization, Activation, LSTM, Lambda, Reshape, GRU
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from research.dataImporting import dataTools
import keras.backend as K
from tcn import TCN
from keras import regularizers

# %%
training_df_raw=pd.read_csv("0.5s_raw_range_A1_A2_A3_no_overlap.csv")

# %%
phone_slots=["Phone_6-2","Phone_29","Phone_8","Phone_2-4","Phone_1-1","Phone_12","Phone_6-3","Phone_27","Phone_7-1","Phone_5-4","Phone_2-3","Phone_3-1","Phone_15","Phone_10","Phone_1-3","Phone_6-4","Phone_28","Phone_3-5","Phone_3-4","Phone_3-2","Phone_2-5","Phone_5-3","Phone_30","Phone_6-5","Phone_11","Phone_5-2","Phone_9","Phone_7-2"]

cluster_1=["Phone_6-2","Phone_29","Phone_8","Phone_2-4","Phone_1-1","Phone_12","Phone_6-3","Phone_27"]
cluster_2=["Phone_7-1","Phone_5-4","Phone_2-3","Phone_3-1","Phone_15","Phone_10","Phone_1-3","Phone_6-4"]
cluster_3=["Phone_28","Phone_3-5","Phone_3-4","Phone_3-2","Phone_2-5","Phone_5-3","Phone_30","Phone_6-5","Phone_11","Phone_5-2","Phone_9","Phone_7-2"]

bad_runs=["A3R6P1","A3R4P4","A3R4P5","A3R3P4","A3R3P5"]
good_runs_IF=["A1R1P1","A1R1P2","A1R1P3","A1R1P4","A1R1P5","A2R1P1","A2R1P2","A2R1P3","A2R1P4","A2R1P5","A2R2P1","A2R2P2","A2R2P3","A2R2P4","A2R2P5"]
good_runs_matrice=["A1R2P2","A1R2P","A1R2P4","A1R2P5","A2R3P1","A2R3P2","A2R4P1","A2R4P2","A2R4P3","A3R3P1","A3R3P2","A3R4P2","A3R4P3","A3R4P5"]
good_runs_phantom=["A2R5P1","A2R5P2","A2R5P3","A2R5P4","A2R5P5","A2R6P1","A2R6P2","A2R6P3","A2R6P4","A2R6P5","A3R5P1","A3R5P2","A3R5P3","A3R5P4","A3R6P1","A3R6P2","A3R6P3","A3R6P4"]
test_runs_matrice=["A2R3P3","A3R3P3"]
notable_col_names=['Pass','Segment','Phone','Lat','Lon','Alt','Range']
passes_df=pd.read_csv(r"C:\Users\rclendening\researchData\researchCSVs_Scripts_etc\A1_A2_A3_flight_directory.csv")
x_data=[]
y_data=[]
def melspect(audioData, Fs):
    '''
    Converts decoded wav file to MFCC feature space
    @param audioData: Numpy array of decoded audio wav file
    @return MFCC coefficients
    '''
    data= audioData.astype(float)
    # spect = melspectrogram(y=data,sr=Fs, hop_length=1024,n_mels=64, n_fft=2048)
    spect = melspectrogram(y=data,sr=Fs)
    return spect
x_data=[]
y_data=[]
thd_frame=[]
range_frame=[]
for x in passes_df.iterrows():
    row=x[1]
    pass_num=row[0]
    scenario=row[1]
    run_num=row[2]
    start=row[3]
    stop=row[4]
    drone_gps_file=row[5]
    full_name=(str(scenario) + 'R' + str(run_num) + 'P' + str(pass_num)).strip()
    pass_df=training_df_raw.loc[training_df_raw[str(notable_col_names.index('Pass'))] == full_name]
    #pass_df=training_df.loc[training_df["Pass"] == full_name]
    max_segment=pass_df[str(notable_col_names.index('Segment'))].max()
    #max_segment=pass_df["Segment"].max()
    #for i in range(0,max_segment):
    print(full_name)
    if full_name in good_runs_IF:
        drone_type=1
    elif full_name in good_runs_matrice:
        drone_type=0
    else:
        drone_type=2
    if full_name in good_runs_matrice or full_name in good_runs_IF or full_name in good_runs_phantom:
    #if full_name in good_runs_phantom:
        for i in range(0,max_segment):
            clust_1=[]
            clust_2=[]
            clust_3=[]
            frame_df=pass_df.loc[pass_df[str(notable_col_names.index('Segment'))]==i]
            if len(frame_df != 0):
                thd_frame=[]
                range_frame=[]
                for phone in phone_slots:
                    if phone in cluster_1:
                        cluster=1
                    elif phone in cluster_2:
                        cluster=2
                    elif phone in cluster_3:
                        cluster=3
                #for i in range(0,max_segment):
                    #frame_df=phone_seg.loc[phone_seg[str(notable_col_names.index('Segment'))]==i]
                    phone_seg=frame_df.loc[frame_df[str(notable_col_names.index('Phone'))]==phone]
                #phone_seg=frame_df.loc[frame_df["Name"]==phone]
                    data=np.array(phone_seg.iloc[:,8:4008])
                    #data=np.array(frame_df.iloc[:,8:16008])
                    if np.any(data):
                        mel_data=melspect(data[0],8000)
                    else:
                        mel_data=np.zeros((128,8))
                #data=np.array(frame_df.iloc[:,-512:])
                # dist=phone_seg[str(notable_col_names.index('Range'))]
                    dist=phone_seg[str(notable_col_names.index('Range'))]
                #dist=phone_seg["Range"]
                    if len(np.array(dist)>0):
                            data=data[0]
                            #data=np.reshape(data,(64,4))
                            #data=np.reshape(data,(40,1))
                            dist=np.array(dist)[0]
                            if phone in cluster_1:
                                clust_1.append(dist)
                            elif phone in cluster_2:
                                clust_2.append(dist)
                            elif phone in cluster_3:
                                clust_3.append(dist)
                    thd_frame.append(mel_data)
                # range_frame.append([class_value,drone_type,dist])
                range_frame=np.argmin([np.average(np.array(clust_1)),np.average(np.array(clust_2)),np.average(np.array(clust_3))])
            #y_vals= rangeClosest(range_frame)
                x_data.append(np.array(thd_frame))
                y_data.append(range_frame)
# Out:
# A1R1P1
# A1R1P2
# A1R1P3
# A1R1P4
# A1R1P5
# A1R2P1
# A1R2P2
# A1R2P3
# A1R2P4
# A1R2P5
# A2R1P1
# A2R1P2
# A2R1P3
# C:\Users\rclendening\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\rclendening\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# A2R1P4
# A2R1P5
# A2R2P1
# A2R2P2
# A2R2P3
# A2R2P4
# A2R2P5
# A2R3P1
# A2R3P2
# A2R3P3
# A2R4P1
# A2R4P2
# A2R4P3
# A2R5P1
# A2R5P2
# A2R5P3
# A2R5P4
# A2R5P5
# A2R6P1
# A2R6P2
# A2R6P3
# A2R6P4
# A2R6P5
# A2R7P1
# A2R7P2
# A2R7P3
# A2R7P4
# A2R7P5
# A2R8P1
# A2R8P2
# A2R8P3
# A2R8P4
# A2R8P5
# A3R3P1
# A3R3P2
# A3R3P3
# A3R3P4
# A3R3P5
# A3R4P1
# A3R4P2
# A3R4P3
# A3R4P4
# A3R4P5
# A3R5P1
# A3R5P2
# A3R5P3
# A3R5P4
# A3R6P1
# A3R6P2
# A3R6P3
# A3R6P4

# %%
x_data=np.array(x_data)
x_data=np.float32(x_data)
y_data=np.array(y_data)
train_feats,test_feats,train_targs,test_targs=train_test_split(x_data,y_data,test_size=0.2,shuffle=True,random_state=42)

# %%
plt.hist(y_data)
plt.title("Data Distribution (Proximity to Clusters)")
plt.xlabel("Cluster Class")
plt.savefig("./Plots/earlyDF_distro.pdf")

# %%
from sklearn.utils import class_weight
# class_weights=class_weight.compute_class_weight('balanced', classes=np.unique(class_train_targs), y=class_train_targs)
# class_weights={0:class_weights[0], 1:class_weights[1]}
#print(class_weights)
range_weights=class_weight.compute_class_weight('balanced', classes=np.unique(train_targs), y=train_targs)
#,4:range_weights[4],5:range_weights[5], 6:range_weights[6]
range_weights={0:range_weights[0], 1:range_weights[1],2:range_weights[2]}
print(range_weights)
# Out:
# {0: 0.8555971702039118, 1: 3.7968605724838413, 2: 0.6378160384675042}

# %%
modelCNN_MCV2=tf.keras.Sequential()
modelCNN_MCV2.add(BatchNormalization(input_shape=(28,128,8)))
modelCNN_MCV2.add(Conv2D(filters=8,kernel_size=(3,3),strides=(1,1),padding='SAME', use_bias=False, name='conv_1'))
modelCNN_MCV2.add(BatchNormalization())
modelCNN_MCV2.add(Activation('leaky_relu'))
modelCNN_MCV2.add(MaxPooling2D(2))
modelCNN_MCV2.add(Conv2D(filters=16,kernel_size=(3,3),strides=(2,2), use_bias=False,
                         padding='SAME', name='conv_2'))
modelCNN_MCV2.add(BatchNormalization())
modelCNN_MCV2.add(Activation('leaky_relu'))
modelCNN_MCV2.add(Dropout(0.3))
modelCNN_MCV2.add(Conv2D(filters=32,kernel_size=(3,3),strides=(2,2), use_bias=False,
                         padding='SAME', name='conv_3'))
modelCNN_MCV2.add(BatchNormalization())
modelCNN_MCV2.add(Activation('leaky_relu'))
modelCNN_MCV2.add(Dropout(0.3))
modelCNN_MCV2.add(Flatten())
modelCNN_MCV2.add(Dense(256, activation='leaky_relu', name='dense_2'))
modelCNN_MCV2.add(Dense(128, activation='leaky_relu', name='dense_3'))
modelCNN_MCV2.add(Dropout(0.5))
modelCNN_MCV2.add(Dense(3, activation='softmax', name='output_range'))
optimizer= tf.keras.optimizers.Adam()
modelCNN_MCV2.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])


reduceLR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                 verbose=1, patience=20, mode='auto')
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4,
                          patience=40, mode='auto', restore_best_weights=True)
modelCNN_MCV2.build(input_shape=(None,128,8,1))
modelCNN_MCV2.summary()
single_drone_train_targs_oh=tf.keras.utils.to_categorical(train_targs,num_classes=3)
single_drone_train_data=np.array(train_feats)
history = modelCNN_MCV2.fit(single_drone_train_data, single_drone_train_targs_oh,
                      epochs=200,
                      batch_size=32,
                      shuffle=True,
                      class_weight=range_weights,
                      validation_split=0.2,
                      callbacks=[reduceLR, early])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_30 (Bat  (None, 28, 128, 8)       32
#  chNormalization)
#
#  conv_1 (Conv2D)             (None, 28, 128, 8)        576
#
#  batch_normalization_31 (Bat  (None, 28, 128, 8)       32
#  chNormalization)
#
#  activation_22 (Activation)  (None, 28, 128, 8)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 64, 8)        0
#  2D)
#
#  conv_2 (Conv2D)             (None, 7, 32, 16)         1152
#
#  batch_normalization_32 (Bat  (None, 7, 32, 16)        64
#  chNormalization)
#
#  activation_23 (Activation)  (None, 7, 32, 16)         0
#
#  dropout_14 (Dropout)        (None, 7, 32, 16)         0
#
#  conv_3 (Conv2D)             (None, 4, 16, 32)         4608
#
#  batch_normalization_33 (Bat  (None, 4, 16, 32)        128
#  chNormalization)
#
#  activation_24 (Activation)  (None, 4, 16, 32)         0
#
#  dropout_15 (Dropout)        (None, 4, 16, 32)         0
#
#  flatten_7 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 256)               524544
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  output_range (Dense)        (None, 3)                 387
#
# =================================================================
# Total params: 564,419
# Trainable params: 564,291
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/200
# 103/103 [==============================] - 10s 78ms/step - loss: 0.9232 - accuracy: 0.6041 - val_loss: 0.5444 - val_accuracy: 0.7849 - lr: 0.0010
# Epoch 2/200
# 103/103 [==============================] - 9s 87ms/step - loss: 0.6350 - accuracy: 0.7385 - val_loss: 0.4782 - val_accuracy: 0.8177 - lr: 0.0010
# Epoch 3/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.5404 - accuracy: 0.7768 - val_loss: 0.4120 - val_accuracy: 0.8275 - lr: 0.0010
# Epoch 4/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.4612 - accuracy: 0.8088 - val_loss: 0.3936 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 5/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.3865 - accuracy: 0.8291 - val_loss: 0.3806 - val_accuracy: 0.8396 - lr: 0.0010
# Epoch 6/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.3603 - accuracy: 0.8465 - val_loss: 0.2978 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 7/200
# 103/103 [==============================] - 7s 63ms/step - loss: 0.3078 - accuracy: 0.8632 - val_loss: 0.3545 - val_accuracy: 0.8566 - lr: 0.0010
# Epoch 8/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.3056 - accuracy: 0.8629 - val_loss: 0.2853 - val_accuracy: 0.8773 - lr: 0.0010
# Epoch 9/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.2662 - accuracy: 0.8820 - val_loss: 0.2712 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 10/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.2546 - accuracy: 0.8866 - val_loss: 0.3101 - val_accuracy: 0.8712 - lr: 0.0010
# Epoch 11/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.2667 - accuracy: 0.8851 - val_loss: 0.2571 - val_accuracy: 0.8894 - lr: 0.0010
# Epoch 12/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.2343 - accuracy: 0.8978 - val_loss: 0.2339 - val_accuracy: 0.9004 - lr: 0.0010
# Epoch 13/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.2312 - accuracy: 0.8927 - val_loss: 0.2313 - val_accuracy: 0.9028 - lr: 0.0010
# Epoch 14/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.2079 - accuracy: 0.9018 - val_loss: 0.2165 - val_accuracy: 0.9235 - lr: 0.0010
# Epoch 15/200
# 103/103 [==============================] - 8s 74ms/step - loss: 0.2313 - accuracy: 0.9054 - val_loss: 0.2192 - val_accuracy: 0.9077 - lr: 0.0010
# Epoch 16/200
# 103/103 [==============================] - 7s 72ms/step - loss: 0.2038 - accuracy: 0.9091 - val_loss: 0.2169 - val_accuracy: 0.9125 - lr: 0.0010
# Epoch 17/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.1996 - accuracy: 0.9146 - val_loss: 0.2065 - val_accuracy: 0.9089 - lr: 0.0010
# Epoch 18/200
# 103/103 [==============================] - 7s 72ms/step - loss: 0.1804 - accuracy: 0.9188 - val_loss: 0.2015 - val_accuracy: 0.9162 - lr: 0.0010
# Epoch 19/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.1404 - accuracy: 0.9292 - val_loss: 0.1860 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 20/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.1671 - accuracy: 0.9276 - val_loss: 0.2169 - val_accuracy: 0.9089 - lr: 0.0010
# Epoch 21/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.1827 - accuracy: 0.9173 - val_loss: 0.2196 - val_accuracy: 0.8991 - lr: 0.0010
# Epoch 22/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.1474 - accuracy: 0.9267 - val_loss: 0.1800 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 23/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.1397 - accuracy: 0.9401 - val_loss: 0.2022 - val_accuracy: 0.9149 - lr: 0.0010
# Epoch 24/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.1497 - accuracy: 0.9410 - val_loss: 0.2288 - val_accuracy: 0.9162 - lr: 0.0010
# Epoch 25/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.1571 - accuracy: 0.9349 - val_loss: 0.1893 - val_accuracy: 0.9198 - lr: 0.0010
# Epoch 26/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.1519 - accuracy: 0.9352 - val_loss: 0.1881 - val_accuracy: 0.9295 - lr: 0.0010
# Epoch 27/200
# 103/103 [==============================] - 7s 63ms/step - loss: 0.1391 - accuracy: 0.9346 - val_loss: 0.1815 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 28/200
# 103/103 [==============================] - 7s 73ms/step - loss: 0.1136 - accuracy: 0.9529 - val_loss: 0.1933 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 29/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.1305 - accuracy: 0.9395 - val_loss: 0.1860 - val_accuracy: 0.9271 - lr: 0.0010
# Epoch 30/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.1422 - accuracy: 0.9355 - val_loss: 0.1849 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 31/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.1196 - accuracy: 0.9450 - val_loss: 0.1704 - val_accuracy: 0.9344 - lr: 0.0010
# Epoch 32/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0987 - accuracy: 0.9556 - val_loss: 0.1650 - val_accuracy: 0.9356 - lr: 0.0010
# Epoch 33/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.1100 - accuracy: 0.9510 - val_loss: 0.1959 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 34/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.1128 - accuracy: 0.9544 - val_loss: 0.1825 - val_accuracy: 0.9295 - lr: 0.0010
# Epoch 35/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.1189 - accuracy: 0.9492 - val_loss: 0.1877 - val_accuracy: 0.9332 - lr: 0.0010
# Epoch 36/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.1003 - accuracy: 0.9541 - val_loss: 0.2194 - val_accuracy: 0.9222 - lr: 0.0010
# Epoch 37/200
# 103/103 [==============================] - 8s 79ms/step - loss: 0.1030 - accuracy: 0.9553 - val_loss: 0.1581 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 38/200
# 103/103 [==============================] - 8s 73ms/step - loss: 0.1088 - accuracy: 0.9559 - val_loss: 0.1893 - val_accuracy: 0.9332 - lr: 0.0010
# Epoch 39/200
# 103/103 [==============================] - 7s 72ms/step - loss: 0.0917 - accuracy: 0.9602 - val_loss: 0.2013 - val_accuracy: 0.9332 - lr: 0.0010
# Epoch 40/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.1390 - accuracy: 0.9444 - val_loss: 0.1692 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 41/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.1021 - accuracy: 0.9571 - val_loss: 0.1944 - val_accuracy: 0.9392 - lr: 0.0010
# Epoch 42/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.1153 - accuracy: 0.9541 - val_loss: 0.2109 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 43/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.1013 - accuracy: 0.9529 - val_loss: 0.1913 - val_accuracy: 0.9295 - lr: 0.0010
# Epoch 44/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.1014 - accuracy: 0.9568 - val_loss: 0.2003 - val_accuracy: 0.9392 - lr: 0.0010
# Epoch 45/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0839 - accuracy: 0.9599 - val_loss: 0.1789 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 46/200
# 103/103 [==============================] - 7s 64ms/step - loss: 0.0901 - accuracy: 0.9596 - val_loss: 0.2373 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 47/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0840 - accuracy: 0.9635 - val_loss: 0.1941 - val_accuracy: 0.9392 - lr: 0.0010
# Epoch 48/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.1222 - accuracy: 0.9529 - val_loss: 0.2127 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 49/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0938 - accuracy: 0.9605 - val_loss: 0.2364 - val_accuracy: 0.9332 - lr: 0.0010
# Epoch 50/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.1033 - accuracy: 0.9577 - val_loss: 0.1648 - val_accuracy: 0.9417 - lr: 0.0010
# Epoch 51/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0876 - accuracy: 0.9623 - val_loss: 0.1597 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 52/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0967 - accuracy: 0.9605 - val_loss: 0.1777 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 53/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0793 - accuracy: 0.9623 - val_loss: 0.1489 - val_accuracy: 0.9490 - lr: 0.0010
# Epoch 54/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0617 - accuracy: 0.9696 - val_loss: 0.1668 - val_accuracy: 0.9417 - lr: 0.0010
# Epoch 55/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0722 - accuracy: 0.9696 - val_loss: 0.2085 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 56/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0815 - accuracy: 0.9614 - val_loss: 0.1861 - val_accuracy: 0.9405 - lr: 0.0010
# Epoch 57/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.1091 - accuracy: 0.9650 - val_loss: 0.1969 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 58/200
# 103/103 [==============================] - 8s 75ms/step - loss: 0.0642 - accuracy: 0.9702 - val_loss: 0.1727 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 59/200
# 103/103 [==============================] - 8s 78ms/step - loss: 0.0751 - accuracy: 0.9666 - val_loss: 0.2288 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 60/200
# 103/103 [==============================] - 11s 106ms/step - loss: 0.0786 - accuracy: 0.9623 - val_loss: 0.1907 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 61/200
# 103/103 [==============================] - 9s 86ms/step - loss: 0.0814 - accuracy: 0.9681 - val_loss: 0.1511 - val_accuracy: 0.9502 - lr: 0.0010
# Epoch 62/200
# 103/103 [==============================] - 8s 79ms/step - loss: 0.0879 - accuracy: 0.9666 - val_loss: 0.1577 - val_accuracy: 0.9465 - lr: 0.0010
# Epoch 63/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0744 - accuracy: 0.9681 - val_loss: 0.1595 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 64/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0873 - accuracy: 0.9659 - val_loss: 0.2056 - val_accuracy: 0.9344 - lr: 0.0010
# Epoch 65/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0843 - accuracy: 0.9638 - val_loss: 0.1546 - val_accuracy: 0.9490 - lr: 0.0010
# Epoch 66/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0785 - accuracy: 0.9681 - val_loss: 0.1732 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 67/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0569 - accuracy: 0.9735 - val_loss: 0.1781 - val_accuracy: 0.9417 - lr: 0.0010
# Epoch 68/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0660 - accuracy: 0.9723 - val_loss: 0.1472 - val_accuracy: 0.9478 - lr: 0.0010
# Epoch 69/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0552 - accuracy: 0.9751 - val_loss: 0.1702 - val_accuracy: 0.9502 - lr: 0.0010
# Epoch 70/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0522 - accuracy: 0.9742 - val_loss: 0.1706 - val_accuracy: 0.9490 - lr: 0.0010
# Epoch 71/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0751 - accuracy: 0.9714 - val_loss: 0.1592 - val_accuracy: 0.9550 - lr: 0.0010
# Epoch 72/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0761 - accuracy: 0.9687 - val_loss: 0.1596 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 73/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0877 - accuracy: 0.9702 - val_loss: 0.1780 - val_accuracy: 0.9478 - lr: 0.0010
# Epoch 74/200
# 103/103 [==============================] - 7s 72ms/step - loss: 0.0725 - accuracy: 0.9659 - val_loss: 0.1748 - val_accuracy: 0.9490 - lr: 0.0010
# Epoch 75/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0876 - accuracy: 0.9669 - val_loss: 0.1799 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 76/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0907 - accuracy: 0.9711 - val_loss: 0.1534 - val_accuracy: 0.9563 - lr: 0.0010
# Epoch 77/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0606 - accuracy: 0.9693 - val_loss: 0.1668 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 78/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0697 - accuracy: 0.9742 - val_loss: 0.1660 - val_accuracy: 0.9502 - lr: 0.0010
# Epoch 79/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0570 - accuracy: 0.9775 - val_loss: 0.1695 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 80/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0658 - accuracy: 0.9790 - val_loss: 0.1741 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 81/200
# 103/103 [==============================] - 7s 72ms/step - loss: 0.0835 - accuracy: 0.9693 - val_loss: 0.1808 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 82/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0448 - accuracy: 0.9808 - val_loss: 0.1859 - val_accuracy: 0.9465 - lr: 0.0010
# Epoch 83/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0438 - accuracy: 0.9802 - val_loss: 0.2027 - val_accuracy: 0.9417 - lr: 0.0010
# Epoch 84/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0539 - accuracy: 0.9796 - val_loss: 0.2019 - val_accuracy: 0.9356 - lr: 0.0010
# Epoch 85/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0410 - accuracy: 0.9815 - val_loss: 0.1645 - val_accuracy: 0.9502 - lr: 0.0010
# Epoch 86/200
# 103/103 [==============================] - 7s 73ms/step - loss: 0.0730 - accuracy: 0.9742 - val_loss: 0.1785 - val_accuracy: 0.9465 - lr: 0.0010
# Epoch 87/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0454 - accuracy: 0.9815 - val_loss: 0.1691 - val_accuracy: 0.9514 - lr: 0.0010
# Epoch 88/200
# 103/103 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9714
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0822 - accuracy: 0.9714 - val_loss: 0.1940 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 89/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0451 - accuracy: 0.9811 - val_loss: 0.1693 - val_accuracy: 0.9514 - lr: 5.0000e-04
# Epoch 90/200
# 103/103 [==============================] - 7s 72ms/step - loss: 0.0442 - accuracy: 0.9811 - val_loss: 0.1651 - val_accuracy: 0.9538 - lr: 5.0000e-04
# Epoch 91/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0425 - accuracy: 0.9805 - val_loss: 0.1668 - val_accuracy: 0.9526 - lr: 5.0000e-04
# Epoch 92/200
# 103/103 [==============================] - 7s 65ms/step - loss: 0.0288 - accuracy: 0.9857 - val_loss: 0.1325 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 93/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0408 - accuracy: 0.9821 - val_loss: 0.1534 - val_accuracy: 0.9623 - lr: 5.0000e-04
# Epoch 94/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0397 - accuracy: 0.9839 - val_loss: 0.1562 - val_accuracy: 0.9550 - lr: 5.0000e-04
# Epoch 95/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0321 - accuracy: 0.9863 - val_loss: 0.1404 - val_accuracy: 0.9526 - lr: 5.0000e-04
# Epoch 96/200
# 103/103 [==============================] - 8s 81ms/step - loss: 0.0276 - accuracy: 0.9869 - val_loss: 0.1250 - val_accuracy: 0.9611 - lr: 5.0000e-04
# Epoch 97/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0251 - accuracy: 0.9891 - val_loss: 0.1386 - val_accuracy: 0.9611 - lr: 5.0000e-04
# Epoch 98/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.0315 - accuracy: 0.9860 - val_loss: 0.1541 - val_accuracy: 0.9575 - lr: 5.0000e-04
# Epoch 99/200
# 103/103 [==============================] - 8s 74ms/step - loss: 0.0259 - accuracy: 0.9881 - val_loss: 0.1844 - val_accuracy: 0.9526 - lr: 5.0000e-04
# Epoch 100/200
# 103/103 [==============================] - 8s 74ms/step - loss: 0.0284 - accuracy: 0.9875 - val_loss: 0.1627 - val_accuracy: 0.9575 - lr: 5.0000e-04
# Epoch 101/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0332 - accuracy: 0.9863 - val_loss: 0.1662 - val_accuracy: 0.9599 - lr: 5.0000e-04
# Epoch 102/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0285 - accuracy: 0.9872 - val_loss: 0.1512 - val_accuracy: 0.9575 - lr: 5.0000e-04
# Epoch 103/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0376 - accuracy: 0.9857 - val_loss: 0.1670 - val_accuracy: 0.9550 - lr: 5.0000e-04
# Epoch 104/200
# 103/103 [==============================] - 7s 73ms/step - loss: 0.0360 - accuracy: 0.9845 - val_loss: 0.1444 - val_accuracy: 0.9599 - lr: 5.0000e-04
# Epoch 105/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0325 - accuracy: 0.9839 - val_loss: 0.1772 - val_accuracy: 0.9563 - lr: 5.0000e-04
# Epoch 106/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0212 - accuracy: 0.9903 - val_loss: 0.1507 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 107/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0426 - accuracy: 0.9860 - val_loss: 0.1724 - val_accuracy: 0.9563 - lr: 5.0000e-04
# Epoch 108/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0277 - accuracy: 0.9875 - val_loss: 0.1675 - val_accuracy: 0.9611 - lr: 5.0000e-04
# Epoch 109/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0254 - accuracy: 0.9881 - val_loss: 0.1562 - val_accuracy: 0.9611 - lr: 5.0000e-04
# Epoch 110/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0235 - accuracy: 0.9921 - val_loss: 0.1793 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 111/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.0182 - accuracy: 0.9921 - val_loss: 0.1835 - val_accuracy: 0.9538 - lr: 5.0000e-04
# Epoch 112/200
# 103/103 [==============================] - 8s 78ms/step - loss: 0.0248 - accuracy: 0.9894 - val_loss: 0.1770 - val_accuracy: 0.9563 - lr: 5.0000e-04
# Epoch 113/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0305 - accuracy: 0.9872 - val_loss: 0.2110 - val_accuracy: 0.9502 - lr: 5.0000e-04
# Epoch 114/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0233 - accuracy: 0.9909 - val_loss: 0.1863 - val_accuracy: 0.9550 - lr: 5.0000e-04
# Epoch 115/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0277 - accuracy: 0.9869 - val_loss: 0.2025 - val_accuracy: 0.9502 - lr: 5.0000e-04
# Epoch 116/200
# 103/103 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9900
# Epoch 116: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 103/103 [==============================] - 7s 68ms/step - loss: 0.0212 - accuracy: 0.9900 - val_loss: 0.2168 - val_accuracy: 0.9478 - lr: 5.0000e-04
# Epoch 117/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0195 - accuracy: 0.9912 - val_loss: 0.2048 - val_accuracy: 0.9550 - lr: 2.5000e-04
# Epoch 118/200
# 103/103 [==============================] - 8s 75ms/step - loss: 0.0156 - accuracy: 0.9936 - val_loss: 0.2082 - val_accuracy: 0.9550 - lr: 2.5000e-04
# Epoch 119/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0207 - accuracy: 0.9912 - val_loss: 0.1942 - val_accuracy: 0.9575 - lr: 2.5000e-04
# Epoch 120/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0169 - accuracy: 0.9924 - val_loss: 0.1965 - val_accuracy: 0.9587 - lr: 2.5000e-04
# Epoch 121/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 0.1899 - val_accuracy: 0.9563 - lr: 2.5000e-04
# Epoch 122/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.2142 - val_accuracy: 0.9526 - lr: 2.5000e-04
# Epoch 123/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0113 - accuracy: 0.9942 - val_loss: 0.1868 - val_accuracy: 0.9538 - lr: 2.5000e-04
# Epoch 124/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.1905 - val_accuracy: 0.9538 - lr: 2.5000e-04
# Epoch 125/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0170 - accuracy: 0.9927 - val_loss: 0.1974 - val_accuracy: 0.9550 - lr: 2.5000e-04
# Epoch 126/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 0.2012 - val_accuracy: 0.9587 - lr: 2.5000e-04
# Epoch 127/200
# 103/103 [==============================] - 7s 69ms/step - loss: 0.0269 - accuracy: 0.9897 - val_loss: 0.1899 - val_accuracy: 0.9550 - lr: 2.5000e-04
# Epoch 128/200
# 103/103 [==============================] - 7s 67ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 0.1918 - val_accuracy: 0.9526 - lr: 2.5000e-04
# Epoch 129/200
# 103/103 [==============================] - 7s 71ms/step - loss: 0.0124 - accuracy: 0.9945 - val_loss: 0.1782 - val_accuracy: 0.9563 - lr: 2.5000e-04
# Epoch 130/200
# 103/103 [==============================] - 8s 77ms/step - loss: 0.0129 - accuracy: 0.9945 - val_loss: 0.1786 - val_accuracy: 0.9538 - lr: 2.5000e-04
# Epoch 131/200
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0148 - accuracy: 0.9924 - val_loss: 0.1714 - val_accuracy: 0.9575 - lr: 2.5000e-04
# Epoch 132/200
# 103/103 [==============================] - 8s 77ms/step - loss: 0.0167 - accuracy: 0.9942 - val_loss: 0.1768 - val_accuracy: 0.9575 - lr: 2.5000e-04
# Epoch 133/200
# 103/103 [==============================] - 8s 78ms/step - loss: 0.0193 - accuracy: 0.9921 - val_loss: 0.1822 - val_accuracy: 0.9550 - lr: 2.5000e-04
# Epoch 134/200
# 103/103 [==============================] - 7s 68ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.1798 - val_accuracy: 0.9550 - lr: 2.5000e-04
# Epoch 135/200
# 103/103 [==============================] - 7s 66ms/step - loss: 0.0174 - accuracy: 0.9909 - val_loss: 0.1795 - val_accuracy: 0.9563 - lr: 2.5000e-04
# Epoch 136/200
# 103/103 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9942
# Epoch 136: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 103/103 [==============================] - 7s 70ms/step - loss: 0.0124 - accuracy: 0.9942 - val_loss: 0.1789 - val_accuracy: 0.9563 - lr: 2.5000e-04

# %%
single_drone_test_targs_oh=tf.keras.utils.to_categorical(test_targs,num_classes=3)
modelCNN_MCV2.evaluate(test_feats,single_drone_test_targs_oh)
preds=modelCNN_MCV2.predict(test_feats)
# Out:
# 33/33 [==============================] - 0s 9ms/step - loss: 0.1176 - accuracy: 0.9611
# 33/33 [==============================] - 0s 9ms/step

# %%
balanced_accuracy_score(np.argmax(preds,axis=-1),test_targs)
# Out:
# 0.9439183786271435

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_targs, np.argmax(preds,axis=-1))
## Get Class Labels
class_names = ["Cluster #1","Cluster #2","Cluster #3"]
#class_names = ["<40","40-60","60-80",">80"]
# Plot confusion matrix in a beautiful manner
fig = plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted', fontsize=20)
ax.xaxis.set_label_position('bottom')
plt.xticks(rotation=90)
ax.xaxis.set_ticklabels(class_names, fontsize = 10)
ax.xaxis.tick_bottom()
ax.set_ylabel('True', fontsize=20)
ax.yaxis.set_ticklabels(class_names, fontsize = 10)
plt.yticks(rotation=0)
plt.savefig("./Plots/early_df_cm.pdf", bbox_inches="tight")

# %% [markdown]
# # sUAS RAA

# %%
training_df_raw=pd.read_csv("0.5s_raw_range_range_azimuth_anglev2.csv")

# %%
def MFCCCalc(audioData, Fs):
    '''
    Converts decoded wav file to MFCC feature space
    @param audioData: Numpy array of decoded audio wav file
    @return MFCC coefficients
    '''
    #audioData=audioData.numpy()
    data= audioData.astype(float)
    #coefs = mfcc(data, sr=sampleRate, hop_length=2048)
    coefs = mfcc(y=data, hop_length=8000,n_mfcc=40, sr=Fs)
    return coefs
#cluster_3=["Phone_28","Phone_3-5","Phone_3-4","Phone_3-2","Phone_2-5","Phone_5-3","Phone_30","Phone_6-5","Phone_11","Phone_5-2","Phone_9","Phone_7-2"]
cluster_3_TDoA=["Phone_28","Phone_3-4","Phone_3-2","Phone_2-5","Phone_5-3","Phone_30","Phone_6-5","Phone_11","Phone_5-2","Phone_9","Phone_7-2"]

bad_runs=["A3R6P1","A3R4P4","A3R4P5","A3R3P4","A3R3P5"]
good_runs_IF=["A1R1P1","A1R1P2","A1R1P3","A1R1P4","A1R1P5","A2R1P1","A2R1P2","A2R1P3","A2R1P4","A2R1P5","A2R2P1","A2R2P2","A2R2P3","A2R2P4","A2R2P5"]
good_runs_matrice=["A1R2P2","A1R2P3","A1R2P4","A1R2P5","A2R3P1","A2R3P2","A2R4P1","A2R4P2","A2R4P3","A3R3P1","A3R3P2","A3R4P2","A3R4P3","A3R4P5"]
good_runs_phantom=["A2R5P1","A2R5P2","A2R5P3","A2R5P4","A2R5P5","A2R6P1","A2R6P2","A2R6P3","A2R6P4","A2R6P5","A3R5P1","A3R5P2","A3R5P3","A3R5P4","A3R6P1","A3R6P2","A3R6P3","A3R6P4"]
test_runs_matrice=["A2R3P3","A3R3P3"]
notable_col_names=['Pass','Segment','Phone','Lat','Lon','Alt','Range']
passes_df=pd.read_csv(r"C:\Users\rclendening\researchData\researchCSVs_Scripts_etc\A1_A2_A3_flight_directory.csv")
x_data=[]
y_data=[]
def melspect(audioData, Fs):
    '''
    Converts decoded wav file to MFCC feature space
    @param audioData: Numpy array of decoded audio wav file
    @return MFCC coefficients
    '''
    data= audioData.astype(float)
    # spect = melspectrogram(y=data,sr=Fs, hop_length=1024,n_mels=64, n_fft=2048)
    spect = melspectrogram(y=data,sr=Fs)
    return spect
def phaseSpect(audioData, Fs):
    '''
    Converts decoded wav file to MFCC feature space
    @param audioData: Numpy array of decoded audio wav file
    @return MFCC coefficients
    '''
    data= audioData.astype(float)
    # spect = melspectrogram(y=data,sr=Fs, hop_length=1024,n_mels=64, n_fft=2048)
    x_=np.squeeze(audioData)
    spect = signal.spectrogram(x=x_,fs=Fs,mode='complex')
    return spect[2]

def TDoA(y1, y2, sr):
    y1_=np.squeeze(y1)/1000
    y2_=np.squeeze(y2)/1000
    # print(len(y1_),len(y2_))
    n = len(y1_)
    corr = signal.correlate(y2_, y1_, mode='same') / np.sqrt(signal.correlate(y1_, y1_, mode='same')[int(n/2)] * signal.correlate(y2_, y2_, mode='same')[int(n/2)])
    delay_arr = np.linspace(-0.5*n/sr, 0.5*n/sr, n)
    delay = delay_arr[np.argmax(corr)]
    return delay

x_data=[]
angle_data=[]
range_data=[]
azimuth_data=[]
thd_frame=[]
range_frame=[]
for x in passes_df.iterrows():
    row=x[1]
    pass_num=row[0]
    scenario=row[1]
    run_num=row[2]
    start=row[3]
    stop=row[4]
    if scenario != "A1":
        drone_gps_file=row[5]
        full_name=(str(scenario) + 'R' + str(run_num) + 'P' + str(pass_num)).strip()
        pass_df=training_df_raw.loc[training_df_raw[str(notable_col_names.index('Pass'))] == full_name]
        #pass_df=training_df.loc[training_df["Pass"] == full_name]
        max_segment=pass_df[str(notable_col_names.index('Segment'))].max()
        #max_segment=pass_df["Segment"].max()
        #for i in range(0,max_segment):
        print(full_name)
        if full_name in good_runs_IF:
            drone_type=1
        elif full_name in good_runs_matrice:
            drone_type=0
        else:
            drone_type=2
        if full_name in good_runs_matrice or full_name in good_runs_IF or full_name in good_runs_phantom:
        #if full_name in good_runs_phantom:
            for i in range(0,max_segment):
                clust_3=[]
                frame_df=pass_df.loc[pass_df[str(notable_col_names.index('Segment'))]==i]
                if len(frame_df != 0):
                    range_dist=frame_df.iloc[0][7]
                    angle=frame_df.iloc[0][8]
                    azimuth=frame_df.iloc[0][9]
                    thd_frame=[]
                    range_frame=[]
                    # reference_data=np.array(frame_df.loc[frame_df[str(notable_col_names.index('Phone'))]=='Phone_3-5'].iloc[:,10:4010])
                    for phone in cluster_3:
                        # if phone in cluster_1:
                        #     cluster=1
                        # elif phone in cluster_2:
                        #     cluster=2
                        # elif phone in cluster_3:
                        #     cluster=3
                    #for i in range(0,max_segment):
                        #frame_df=phone_seg.loc[phone_seg[str(notable_col_names.index('Segment'))]==i]
                        phone_seg=frame_df.loc[frame_df[str(notable_col_names.index('Phone'))]==phone]
                    #phone_seg=frame_df.loc[frame_df["Name"]==phone]
                        data=np.array(phone_seg.iloc[:,10:4010])
                        if np.any(data):
                            mel_data=phaseSpect(data,8000)
                        else:
                            mel_data=np.zeros((129,17))
                            #mel_data=0
                        thd_frame.append(mel_data)
                    if range_dist<200:
                        x_data.append(np.array(thd_frame))
                        range_data.append(range_dist)
                        angle_data.append(angle)
                        azimuth_data.append(azimuth)
# Out:
# A2R1P1
# A2R1P2
# A2R1P3
# A2R1P4
# A2R1P5
# A2R2P1
# A2R2P2
# A2R2P3
# A2R2P4
# A2R2P5
# A2R3P1
# A2R3P2
# A2R3P3
# A2R4P1
# A2R4P2
# A2R4P3
# A2R5P1
# A2R5P2
# A2R5P3
# A2R5P4
# A2R5P5
# A2R6P1
# A2R6P2
# A2R6P3
# A2R6P4
# A2R6P5
# A2R7P1
# A2R7P2
# A2R7P3
# A2R7P4
# A2R7P5
# A2R8P1
# A2R8P2
# A2R8P3
# A2R8P4
# A2R8P5
# A3R3P1
# A3R3P2
# A3R3P3
# A3R3P4
# A3R3P5
# A3R4P1
# A3R4P2
# A3R4P3
# A3R4P4
# A3R4P5
# A3R5P1
# A3R5P2
# A3R5P3
# A3R5P4
# A3R6P1
# A3R6P2
# A3R6P3
# A3R6P4

# %%
def subsample(x_data,y_data):
    new_x=[]
    new_y=[]
    rng=np.random.default_rng(12345)
    for x in range(len(x_data)):
        rand_vals=rng.integers(low=1,high=5,size=1)
        if -10<y_data[x]<0 and rand_vals==2:
            new_x.append(x_data[x])
            new_y.append(y_data[x])
        elif not -10<y_data[x]<0:
            new_x.append(x_data[x])
            new_y.append(y_data[x])
    return np.array(new_x), np.array(new_y)
new_x,new_y=subsample(x_data,azimuth_data)

# %%
#new_azimuth=np.array(np.array(azimuth_data)>0, dtype=int)
plt.title("Range Distance from COM")
plt.xlabel("Meters")
plt.ylabel("Number of samples")
plt.hist(range_data,bins=50)
# Out:
# (array([ 55., 200., 383.,  79.,  55.,  52.,  45.,  39.,  42.,  42.,  31.,
#          43.,  33.,  35.,  40.,  30.,  40.,  24.,  45.,  30.,  34.,  34.,
#          31.,  40.,  34.,  29.,  36.,  30.,  34.,  34.,  29.,  38.,  29.,
#          37.,  28.,  34.,  31.,  32.,  42.,  31.,  35.,  36.,  33.,  43.,
#          58., 105.,  21.,  21.,  23.,  23.]),
#  array([ 29.43198211,  32.84210493,  36.25222775,  39.66235057,
#          43.07247339,  46.4825962 ,  49.89271902,  53.30284184,
#          56.71296466,  60.12308748,  63.5332103 ,  66.94333312,
#          70.35345593,  73.76357875,  77.17370157,  80.58382439,
#          83.99394721,  87.40407003,  90.81419285,  94.22431566,
#          97.63443848, 101.0445613 , 104.45468412, 107.86480694,
#         111.27492976, 114.68505258, 118.09517539, 121.50529821,
#         124.91542103, 128.32554385, 131.73566667, 135.14578949,
#         138.55591231, 141.96603512, 145.37615794, 148.78628076,
#         152.19640358, 155.6065264 , 159.01664922, 162.42677204,
#         165.83689485, 169.24701767, 172.65714049, 176.06726331,
#         179.47738613, 182.88750895, 186.29763177, 189.70775458,
#         193.1178774 , 196.52800022, 199.93812304]),
#  <BarContainer object of 50 artists>)

# %%
modelCNN_MCV2=tf.keras.Sequential()
modelCNN_MCV2.add(BatchNormalization(input_shape=(12,129,17,1)))
modelCNN_MCV2.add(Conv2D(filters=8,kernel_size=(4,4),strides=(1,1),padding='SAME', use_bias=False, name='conv_1'))
modelCNN_MCV2.add(BatchNormalization())
modelCNN_MCV2.add(Activation('relu'))
modelCNN_MCV2.add(MaxPooling3D(2))
modelCNN_MCV2.add(Conv2D(filters=16,kernel_size=(2,2),strides=(2,2), use_bias=False,
                         padding='SAME', name='conv_2'))
modelCNN_MCV2.add(BatchNormalization())
modelCNN_MCV2.add(Activation('relu'))
modelCNN_MCV2.add(Dropout(0.3))
modelCNN_MCV2.add(Conv2D(filters=32,kernel_size=(2,2),strides=(2,2), use_bias=False,
                         padding='SAME', name='conv_3'))
modelCNN_MCV2.add(BatchNormalization())
modelCNN_MCV2.add(Activation('relu'))
modelCNN_MCV2.add(Dropout(0.3))
modelCNN_MCV2.add(Flatten())
modelCNN_MCV2.add(Dense(512, activation='relu', name='dense_2'))
modelCNN_MCV2.add(Dense(256, activation='relu', name='dense_3'))
modelCNN_MCV2.add(Dropout(0.5))
modelCNN_MCV2.add(Dense(1, activation='sigmoid', name='output_range'))
optimizer= tf.keras.optimizers.Adam()
modelCNN_MCV2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])


reduceLR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                 verbose=1, patience=20, mode='auto')
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4,
                          patience=40, mode='auto', restore_best_weights=True)
modelCNN_MCV2.build(input_shape=(12,129,17,1))
modelCNN_MCV2.summary()
x_train=np.array(x_data)
y_train=np.array(new_azimuth)
history = modelCNN_MCV2.fit(x_train, y_train,
                      epochs=200,
                      batch_size=32,
                      shuffle=True,
                      validation_split=0.2,
                      callbacks=[reduceLR, early])
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_53 (Bat  (None, 12, 129, 17, 1)   4
#  chNormalization)
#
#  conv_1 (Conv2D)             (None, 12, 129, 17, 8)    128
#
#  batch_normalization_54 (Bat  (None, 12, 129, 17, 8)   32
#  chNormalization)
#
#  activation_39 (Activation)  (None, 12, 129, 17, 8)    0
#
#  max_pooling3d_7 (MaxPooling  (None, 6, 64, 8, 8)      0
#  3D)
#
#  conv_2 (Conv2D)             (None, 6, 32, 4, 16)      512
#
#  batch_normalization_55 (Bat  (None, 6, 32, 4, 16)     64
#  chNormalization)
#
#  activation_40 (Activation)  (None, 6, 32, 4, 16)      0
#
#  dropout_37 (Dropout)        (None, 6, 32, 4, 16)      0
#
#  conv_3 (Conv2D)             (None, 6, 16, 2, 32)      2048
#
#  batch_normalization_56 (Bat  (None, 6, 16, 2, 32)     128
#  chNormalization)
#
#  activation_41 (Activation)  (None, 6, 16, 2, 32)      0
#
#  dropout_38 (Dropout)        (None, 6, 16, 2, 32)      0
#
#  flatten_13 (Flatten)        (None, 6144)              0
#
#  dense_2 (Dense)             (None, 512)               3146240
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_39 (Dropout)        (None, 256)               0
#
#  output_range (Dense)        (None, 1)                 257
#
# =================================================================
# Total params: 3,280,741
# Trainable params: 3,280,627
# Non-trainable params: 114
# _________________________________________________________________
# Epoch 1/200
# 61/61 [==============================] - 26s 401ms/step - loss: 0.7120 - accuracy: 0.6490 - val_loss: 0.6878 - val_accuracy: 0.5394 - lr: 0.0010
# Epoch 2/200
# 61/61 [==============================] - 26s 419ms/step - loss: 0.5250 - accuracy: 0.7430 - val_loss: 0.6721 - val_accuracy: 0.5705 - lr: 0.0010
# Epoch 3/200
# 61/61 [==============================] - 28s 465ms/step - loss: 0.4526 - accuracy: 0.7783 - val_loss: 0.6438 - val_accuracy: 0.5975 - lr: 0.0010
# Epoch 4/200
# 61/61 [==============================] - 36s 591ms/step - loss: 0.3657 - accuracy: 0.8328 - val_loss: 0.6035 - val_accuracy: 0.6929 - lr: 0.0010
# Epoch 5/200
# 61/61 [==============================] - 34s 562ms/step - loss: 0.2900 - accuracy: 0.8847 - val_loss: 0.7025 - val_accuracy: 0.5954 - lr: 0.0010
# Epoch 6/200
# 61/61 [==============================] - 37s 612ms/step - loss: 0.2650 - accuracy: 0.8879 - val_loss: 0.5961 - val_accuracy: 0.7095 - lr: 0.0010
# Epoch 7/200
# 61/61 [==============================] - 37s 600ms/step - loss: 0.2003 - accuracy: 0.9242 - val_loss: 0.6860 - val_accuracy: 0.6494 - lr: 0.0010
# Epoch 8/200
# 61/61 [==============================] - 38s 625ms/step - loss: 0.1484 - accuracy: 0.9429 - val_loss: 0.6270 - val_accuracy: 0.7137 - lr: 0.0010
# Epoch 9/200
# 61/61 [==============================] - 39s 647ms/step - loss: 0.1391 - accuracy: 0.9481 - val_loss: 0.7923 - val_accuracy: 0.6515 - lr: 0.0010
# Epoch 10/200
# 61/61 [==============================] - 39s 635ms/step - loss: 0.1196 - accuracy: 0.9559 - val_loss: 0.7642 - val_accuracy: 0.6763 - lr: 0.0010
# Epoch 11/200
# 61/61 [==============================] - 41s 680ms/step - loss: 0.1087 - accuracy: 0.9611 - val_loss: 0.7767 - val_accuracy: 0.6826 - lr: 0.0010
# Epoch 12/200
# 61/61 [==============================] - 40s 651ms/step - loss: 0.0834 - accuracy: 0.9678 - val_loss: 0.7847 - val_accuracy: 0.6660 - lr: 0.0010
# Epoch 13/200
# 61/61 [==============================] - 42s 696ms/step - loss: 0.0777 - accuracy: 0.9730 - val_loss: 0.7064 - val_accuracy: 0.6971 - lr: 0.0010
# Epoch 14/200
# 61/61 [==============================] - 43s 708ms/step - loss: 0.0658 - accuracy: 0.9735 - val_loss: 0.6436 - val_accuracy: 0.7075 - lr: 0.0010
# Epoch 15/200
# 61/61 [==============================] - 41s 668ms/step - loss: 0.0726 - accuracy: 0.9725 - val_loss: 1.1230 - val_accuracy: 0.6349 - lr: 0.0010
# Epoch 16/200
# 61/61 [==============================] - 41s 662ms/step - loss: 0.0537 - accuracy: 0.9787 - val_loss: 0.8896 - val_accuracy: 0.6826 - lr: 0.0010
# Epoch 17/200
# 61/61 [==============================] - 43s 701ms/step - loss: 0.0388 - accuracy: 0.9865 - val_loss: 0.7206 - val_accuracy: 0.7220 - lr: 0.0010
# Epoch 18/200
# 61/61 [==============================] - 42s 684ms/step - loss: 0.0431 - accuracy: 0.9865 - val_loss: 0.8519 - val_accuracy: 0.7220 - lr: 0.0010
# Epoch 19/200
# 61/61 [==============================] - 40s 660ms/step - loss: 0.0454 - accuracy: 0.9823 - val_loss: 0.7931 - val_accuracy: 0.7365 - lr: 0.0010
# Epoch 20/200
# 61/61 [==============================] - 39s 639ms/step - loss: 0.0369 - accuracy: 0.9860 - val_loss: 1.0775 - val_accuracy: 0.7095 - lr: 0.0010
# Epoch 21/200
# 61/61 [==============================] - 40s 659ms/step - loss: 0.0397 - accuracy: 0.9839 - val_loss: 0.9800 - val_accuracy: 0.6929 - lr: 0.0010
# Epoch 22/200
# 61/61 [==============================] - 40s 664ms/step - loss: 0.0365 - accuracy: 0.9844 - val_loss: 0.9929 - val_accuracy: 0.7116 - lr: 0.0010
# Epoch 23/200
# 61/61 [==============================] - 32s 527ms/step - loss: 0.0435 - accuracy: 0.9829 - val_loss: 0.9541 - val_accuracy: 0.7344 - lr: 0.0010
# Epoch 24/200
# 61/61 [==============================] - 33s 533ms/step - loss: 0.0268 - accuracy: 0.9891 - val_loss: 1.0683 - val_accuracy: 0.6867 - lr: 0.0010
# Epoch 25/200
# 61/61 [==============================] - 32s 530ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 1.0174 - val_accuracy: 0.7116 - lr: 0.0010
# Epoch 26/200
# 61/61 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9875
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 61/61 [==============================] - 33s 533ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 1.4009 - val_accuracy: 0.6867 - lr: 0.0010
# Epoch 27/200
# 61/61 [==============================] - 32s 526ms/step - loss: 0.0229 - accuracy: 0.9938 - val_loss: 1.0236 - val_accuracy: 0.6950 - lr: 5.0000e-04
# Epoch 28/200
# 61/61 [==============================] - 32s 525ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.9654 - val_accuracy: 0.7158 - lr: 5.0000e-04
# Epoch 29/200
# 61/61 [==============================] - 32s 526ms/step - loss: 0.0124 - accuracy: 0.9948 - val_loss: 1.0759 - val_accuracy: 0.6888 - lr: 5.0000e-04
# Epoch 30/200
# 61/61 [==============================] - 33s 534ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 1.1106 - val_accuracy: 0.6971 - lr: 5.0000e-04
# Epoch 31/200
# 61/61 [==============================] - 32s 524ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 1.1951 - val_accuracy: 0.7054 - lr: 5.0000e-04
# Epoch 32/200
# 61/61 [==============================] - 32s 527ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 1.1388 - val_accuracy: 0.7220 - lr: 5.0000e-04
# Epoch 33/200
# 61/61 [==============================] - 35s 580ms/step - loss: 0.0128 - accuracy: 0.9979 - val_loss: 1.4542 - val_accuracy: 0.6826 - lr: 5.0000e-04
# Epoch 34/200
# 61/61 [==============================] - 36s 589ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 1.5956 - val_accuracy: 0.6577 - lr: 5.0000e-04
# Epoch 35/200
# 61/61 [==============================] - 37s 600ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 1.3803 - val_accuracy: 0.6888 - lr: 5.0000e-04
# Epoch 36/200
# 61/61 [==============================] - 34s 552ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 1.4363 - val_accuracy: 0.6929 - lr: 5.0000e-04
# Epoch 37/200
# 61/61 [==============================] - 38s 621ms/step - loss: 0.0126 - accuracy: 0.9953 - val_loss: 1.1364 - val_accuracy: 0.7054 - lr: 5.0000e-04
# Epoch 38/200
# 61/61 [==============================] - 38s 623ms/step - loss: 0.0088 - accuracy: 0.9979 - val_loss: 1.4754 - val_accuracy: 0.6515 - lr: 5.0000e-04
# Epoch 39/200
# 61/61 [==============================] - 38s 625ms/step - loss: 0.0028 - accuracy: 0.9984 - val_loss: 1.5326 - val_accuracy: 0.6577 - lr: 5.0000e-04
# Epoch 40/200
# 61/61 [==============================] - 34s 556ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 1.2176 - val_accuracy: 0.7012 - lr: 5.0000e-04
# Epoch 41/200
# 61/61 [==============================] - 45s 734ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 1.3659 - val_accuracy: 0.7075 - lr: 5.0000e-04
# Epoch 42/200
# 61/61 [==============================] - 36s 590ms/step - loss: 0.0030 - accuracy: 0.9984 - val_loss: 1.4121 - val_accuracy: 0.6888 - lr: 5.0000e-04
# Epoch 43/200
# 61/61 [==============================] - 33s 543ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 1.3457 - val_accuracy: 0.6971 - lr: 5.0000e-04
# Epoch 44/200
# 61/61 [==============================] - 32s 520ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 1.4464 - val_accuracy: 0.6992 - lr: 5.0000e-04
# Epoch 45/200
# 61/61 [==============================] - 39s 637ms/step - loss: 0.0176 - accuracy: 0.9964 - val_loss: 1.2741 - val_accuracy: 0.6888 - lr: 5.0000e-04
# Epoch 46/200
# 61/61 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9953
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 61/61 [==============================] - 39s 646ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 1.5378 - val_accuracy: 0.6743 - lr: 5.0000e-04

# %%
from scipy import stats
plt.hist(y_train+30,bins=50)
# Out:
# (array([117.,  90.,  82.,  62.,  53.,  53.,  44.,  55., 342.,  54.,  31.,
#          28.,  23.,  27.,  18.,  21.,  12.,  18.,  17.,  12.,  14.,  17.,
#          14.,  17.,  16.,  19.,  11.,  16.,  12.,  12.,  17.,  13.,  16.,
#          17.,  17.,  18.,  19.,  23.,  24.,  19.,  32.,  24.,  27.,  32.,
#          37.,  47.,  51.,  54.,  67.,  82.]),
#  array([  2.983643  ,   5.73107237,   8.47850173,  11.2259311 ,
#          13.97336047,  16.72078984,  19.46821921,  22.21564858,
#          24.96307795,  27.71050732,  30.45793669,  33.20536605,
#          35.95279542,  38.70022479,  41.44765416,  44.19508353,
#          46.9425129 ,  49.68994227,  52.43737164,  55.18480101,
#          57.93223038,  60.67965974,  63.42708911,  66.17451848,
#          68.92194785,  71.66937722,  74.41680659,  77.16423596,
#          79.91166533,  82.6590947 ,  85.40652406,  88.15395343,
#          90.9013828 ,  93.64881217,  96.39624154,  99.14367091,
#         101.89110028, 104.63852965, 107.38595902, 110.13338839,
#         112.88081775, 115.62824712, 118.37567649, 121.12310586,
#         123.87053523, 126.6179646 , 129.36539397, 132.11282334,
#         134.86025271, 137.60768207, 140.35511144]),
#  <BarContainer object of 50 artists>)
