# %%
import os
import pathlib
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split
from keras import layers
from keras import models
from IPython import display

features = []
labels = []
dataset_path: str = "C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS"
data_dir = pathlib.Path(dataset_path)
droneDict = {  # One hot encoding for labels probs should do it like I did below?
    "IF1200": [1, 0, 0, 0, 0],
    "Matrice_600": [0, 1, 0, 0, 0],
    "Mavic_Pro": [0, 0, 1, 0, 0],
    "Phantom_4_Pro_V2": [0, 0, 0, 1, 0],
    "Noise": [0, 0, 0, 0, 1]
}
droneCountDict = {  # One hot encoding for labels
    "IF1200": 0,
    "Matrice_600": 1,
    "Mavic_Pro": 2,
    "Phantom_4_Pro_V2": 3,
    "Noise": 4
}
dataCount = [0, 0, 0, 0, 0]
drones = np.array(tf.io.gfile.listdir(str(data_dir)))
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
train_files = filenames
# x = round((len(train_files) / 4))
# train_files = train_files[:x]
print("Total num of samples: ", num_samples)
print("Number of examples per label:", len(tf.io.gfile.listdir(str(data_dir / drones[0]))))
print("Example file tensor: ", filenames[0])
print(drones)
print(train_files)
test_file = tf.io.read_file(
    "C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0120210823_6.wav")
test_audio, _ = tf.audio.decode_wav(contents=test_file)
test_audio.shape


def decode_audio(audio_binary):
    audio, _ = tf.audio.decode_wav(contents=audio_binary)
    return tf.squeeze(audio, axis=-1)


def get_label(file_path):
    parts = tf.strings.split(input=file_path, sep=os.path.sep)
    return parts[-2]


def split_audio(waveData, labelName, sampleFreq, frame_duration):
    '''
    Frames audio data and converts to feature space (spectrogram)
    :param waveData: waveData array of time-domain audio
    :param frame_duration: Duration of frames desired
    :param startTime: Start for each clip
    :param sampleFreq: Sample Frequency (8Khz)
    :param labelName: Name of label
    @return list of features (ds), list of labels corresponding to feature dataset:
    '''
    features = []
    label = []
    # middle third of data
    duration = waveData.shape[0]
    startTime = np.round(duration / 3)
    endTime = np.round(duration * 2 / 3)
    frame_dur = frame_duration * sampleFreq
    t1 = startTime
    t2 = t1 + frame_dur
    frame_dur = int(frame_dur)
    t1 = int(t1)
    t2 = int(t2)
    if waveData.shape[0] != 0:
        while t2 < endTime:
            split = waveData[t1:t2]
            t1 = t2
            t2 = t2 + frame_dur
            split = tf.reshape(split, frame_dur)
            split = get_spectrogram(split, frame_dur)
            features.append(split)
            # label.append(labelName)
            dataCount[droneCountDict[labelName]] += 1
            label.append(droneDict[labelName])  # one hot encoding
    return features, label


def create_dataset(train_files):
    '''
    Creates feature dataset and label dataset.
    @param train_files: EagerTensor of file paths.
    @return list of features (ds), list of labels corresponding to feature dataset:
    '''
    i = 0
    features = []
    labels = []
    for x in train_files:
        test_file = tf.io.read_file(x)
        test_audio, sampleRate = tf.audio.decode_wav(contents=test_file)
        x = str(x)
        label = x.split('\\')
        label = label[10]
        test_audio = test_audio[0: test_audio.shape[0] - test_audio.shape[0] % 8000]  # trim to nearest second
        newFeats, newLabs = split_audio(test_audio, label, int(sampleRate), 0.5)
        features.extend(newFeats)
        labels.extend(newLabs)
        i = i + 1

    return features, labels


def get_waveform_and_label(file_path):
    label = get_label(file_path)
    audio_binary = tf.io.read_file(file_path)
    waveform = decode_audio(audio_binary)
    return waveform, label


def get_spectrogram(waveform, length):
    # Zero-padding for an audio waveform with less than length samples
    input_len = length
    waveform = waveform[:input_len]
    zero_padding = tf.zeros(
        [length] - tf.shape(waveform),
        dtype=tf.float32)
    # Cast the waveform tensors' dtype to float32.
    waveform = tf.cast(waveform, dtype=tf.float32)
    # Concatenate the waveform with `zero_padding`, which ensures all audio
    # clips are of the same length.
    equal_length = tf.concat([waveform, zero_padding], 0)
    # Convert the waveform to a spectrogram via a STFT.
    spectrogram = tf.signal.stft(
        equal_length, frame_length=128, frame_step=64)
    # Obtain the magnitude of the STFT.
    spectrogram = tf.abs(spectrogram)
    # Add a `channels` dimension, so that the spectrogram can be used
    # as image-like input data with convolution layers (which expect
    # shape (`batch_size`, `height`, `width`, `channels`).
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram


def grabTrainingSamples(n, trainingData):
    IFCount = 0
    matriceCount = 0
    phantomCount = 0
    mavicCount = 0
    noiseCount = 0
    evenTrainingData = []
    evenLabelData = []
    for i in range(len(labels)):
        lab = trainingData[i][1]
        if lab == [1, 0, 0, 0, 0] and IFCount < n:
            IFCount += 1
            evenTrainingData.append(trainingData[i][0])
            evenLabelData.append(lab)
        elif lab == [0, 1, 0, 0, 0] and matriceCount < n:
            matriceCount += 1
            evenTrainingData.append(trainingData[i][0])
            evenLabelData.append(lab)
        elif lab == [0, 0, 1, 0, 0] and phantomCount < n:
            phantomCount += 1
            evenTrainingData.append(trainingData[i][0])
            evenLabelData.append(lab)
        elif lab == [0, 0, 0, 1, 0] and mavicCount < n:
            mavicCount += 1
            evenTrainingData.append(trainingData[i][0])
            evenLabelData.append(lab)
        elif lab == [0, 0, 0, 0, 1] and noiseCount < n:
            noiseCount += 1
            evenTrainingData.append(trainingData[i][0])
            evenLabelData.append(lab)
    return evenTrainingData, evenLabelData


features, labels = create_dataset(train_files)
newSet = list(zip(features, labels))
random.seed()
random.shuffle(newSet)  # Ensure data is mixed together
n = np.min(dataCount)  # Ensure data is symmetric (aka even amounts of training data for all classes)
print(n)
# features, labels = grabTrainingSamples(n, features, labels)
features, labels = grabTrainingSamples(n, newSet)
print(len(features), len(labels))

trainFeatures, testFeatures, trainTargets, testTargets = train_test_split(features, labels, test_size=0.10,
                                                                          random_state=42)
# trainFeatures = np.asarray(trainFeatures)
# trainTargets = np.asarray(trainTargets)
# mean = trainFeatures.mean(axis=0)
# trainFeatures -= mean
# std = trainFeatures.std(axis=0)
# trainFeatures /= std
# trainFeatures = np.reshape(trainFeatures,
#                             (len(trainFeatures), trainFeatures.shape[1:], 1))
# trainFeatures = np.squeeze(trainFeatures)
# testFeatures = np.asarray(testFeatures)
# testTargets = np.asarray(testTargets)
# testFeatures -= mean
# testFeatures /= std
# testFeatures = np.reshape(testFeatures, (len(testFeatures), numFeat, 1))
# testFeatures = np.squeeze(testFeatures)
trainFeatures=tf.convert_to_tensor(trainFeatures)
testFeatures=tf.convert_to_tensor(testFeatures)
norm_layer = tf.keras.layers.Normalization()
#norm_layer.adapt(np.squeeze(trainFeatures))
norm_layer.adapt(trainFeatures)

print('Input shape:', np.shape(trainFeatures)[1:])
model = models.Sequential([
    layers.Input(shape=np.shape(trainFeatures)[1:]),
    # Downsample the input.
    layers.Resizing(32, 32),
    # Normalize.
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(dataCount)),
])

model.summary()

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
EPOCHS = 10
reduceLR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                 verbose=1, patience=10, mode='auto')
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4,
                          patience=40, mode='auto')
trainFeatures=np.asarray(trainFeatures)
trainTargets=np.asarray(trainTargets)
#trainTargets=tf.convert_to_tensor(trainTargets)
history = model.fit(
    trainFeatures,
    trainTargets,
    epochs=EPOCHS,
    validation_split=0.2,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2)
)
# Out:
# Total num of samples:  875
# Number of examples per label: 239
# Example file tensor:  tf.Tensor(b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_6.wav', shape=(), dtype=string)
# ['IF1200' 'Matrice_600' 'Mavic_Pro' 'Noise' 'Phantom_4_Pro_V2']
# tf.Tensor(
# [b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d304sA1r01p0320210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LY-C-5813_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-A-2426_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-B-2520_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LY-B-5979_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-HT-D-6017_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0120210823_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-FT-A-3405_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-D-2216_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-B-2426_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-B-2499_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-B-2216_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-ID-B-5735_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-FT-B-5871_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-B-2457_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-ID-C-5735_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d306sA1r02p0220210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-HT-D-3386_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PB-B-5794_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-FT-D-5871_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-HT-A-3222_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-C-2132_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d303sA1r01p0220210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PB-C-5794_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-C-2368_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PB-A-5794_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d303sA1r02p0320210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-A-2520_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-HT-B-3386_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-D-2457_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d301sA3r03p0520210827_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-HT-A-3386_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d305sA1r01p0120210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d305sA1r02p0420210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LR-A-5898_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-A-2368_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-D-2171_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d305sA1r02p0120210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-FT-A-3242_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LR-D-5738_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-D-2426_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-B-2132_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d303sA1r02p0420210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-FT-D-3405_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-B-5774_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-B-2372_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-C-2520_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-B-2233_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-D-2132_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-C-5934_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-C-2171_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-D-2368_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-B-2368_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d306sA1r02p0120210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LY-B-5813_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d304sA1r02p0420210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-HT-D-5851_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d306sA1r01p0120210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-C-2478_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d303sA1r02p0220210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d303sA1r01p0320210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-D-5774_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d305sA1r02p0320210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\A0R0P4Phone_3-2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-C-2448_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-FT-B-3242_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0120210823_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-A-2216_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d303sA1r01p0420210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-D-2407_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-A-2132_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-A-2457_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-D-2174_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-A-5934_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-A-5774_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d306sA3r03p0520210827.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d304sA1r01p0520210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-FT-B-6038_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-C-2390_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d306sA1r01p0320210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-HT-C-6017_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LR-B-5738_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PB-D-5794_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LR-D-5898_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0120210823_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-A-2390_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-D-2448_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-C-5774_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\A0R0P1Phone_1-1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-A-2171_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-HT-C-3386_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0220210823_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-ID-D-5735_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-C-2216_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-FT-C-5871_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-A-2478_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d305sA1r01p0220210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-HT-C-5851_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LY-D-5813_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d306sA3r03p0520210827(2).wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0120210823_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\PHANTOM4-FT-B-3405_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0320210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d306sA1r02p0520210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-A-2194_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d303sA1r02p0520210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0120210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d305sA3r03p0520210827(1).wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-C-2372_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_6.wav'
# ...
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-HT-A-5851_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-B-2390_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d303sA3r03p0520210827.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-PF-B-5934_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d305sA3r03p0520210827.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d304sA3r03p0520210827.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0220210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0220210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d301sA3r06p0120210827_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d304sA1r02p0220210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0120210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-C-2426_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-LY-D-2372_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-B-2171_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-C-2541_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d304sA1r02p0520210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0320210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-LR-A-5738_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Noise\\d303sA3r03p0120210827.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-D-2390_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\MAVICPRO-HT-B-5851_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0120210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0120210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0520210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-ID-A-2448_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0420210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0320210826_4.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d304sA1r02p0120210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0320210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0120210823_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d304sA1r01p0420210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0520210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0220210826_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0420210826_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0220210826_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0220210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0220210824_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0320210824_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d306sA1r01p0220210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_12.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r08p0420210826_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0220210826_14.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r04p0120210824_5.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-FT-D-2520_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0520210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA2r03p0320210824_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0220210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0120210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0320210824_13.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-B-2407_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0520210826_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0420210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-RY-B-2478_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d305sA1r01p0520210823.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0420210823_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r05p0520210826_2.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0420210824_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0320210823_11.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0520210826_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0320210826_9.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Mavic_Pro\\d301sA2r07p0420210826_6.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0120210824_7.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0120210826_3.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Phantom_4_Pro_V2\\d301sA2r06p0320210826_15.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0520210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d305sA1r02p0220210824.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA1r01p0520210823_8.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r01p0420210824_1.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\DJIM600-HT-D-2499_20191126.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\IF1200\\d301sA2r02p0120210824_10.wav'
#  b'C:\\Users\\rclendening\\researchData\\Training_Data_NM_RS\\Matrice_600\\d301sA1r02p0220210824_9.wav'], shape=(875,), dtype=string)
# KeyboardInterrupt

# %%
y_pred = np.argmax(model.predict(testFeatures), axis=1)
y_predict=[]
for x in y_pred:
    ans=np.zeros(5)
    ans[x]=1
    y_predict.append(ans)
y_true = testTargets
Sum=0
for x in range(len(y_predict)):
    if y_predict[x].tolist()==y_true[x]:
        Sum+=1
#Sum=sum(y_predict == y_true)
test_acc =Sum/ len(y_true)
print(f'Test set accuracy:', test_acc)
    #callbacks=[reduceLR, early])
    #callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
# Out:
# Test set accuracy: 0.874133949191686
